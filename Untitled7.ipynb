# %%
from sklearn import feature_selection
from scipy import stats
import numpy as np

# %%
X=np.array([1,2,3,4,5])
Y=np.array([5,4,3,2,1])

# %%
a=stats.pearsonr(X, Y)

# %%
list(a)[0]
# Out:
# -1.0

# %%
list(stats.pearsonr(X, Y))[0]
# Out:
# -1.0

# %%
import numpy as np
import astropy.io.fits
import scipy
import sklearn.ensemble
import matplotlib
import matplotlib.pyplot as plt
from astropy.io import fits
from sklearn.metrics import accuracy_score
from sklearn.model_selection import cross_val_score,train_test_split
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import GradientBoostingClassifier,RandomForestClassifier,AdaBoostClassifier,ExtraTreesClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression,PassiveAggressiveClassifier,RidgeClassifier,SGDClassifier
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
from sklearn.model_selection import learning_curve
from sklearn.model_selection import ShuffleSplit


hdulist = fits.open('THEx-catalog.v0_0_3_1.fits')
cols = hdulist[1].columns
print (len(cols.names))
print (len(hdulist[1].data))
print cols
print len((THEx_data))
# Out:
# 639
# 19562
# ColDefs(
#     name = 'event'; format = '30A'
#     name = 'ra'; format = '14A'
#     name = 'dec'; format = '14A'
#     name = 'ra_deg'; format = 'D'
#     name = 'dec_deg'; format = 'D'
#     name = 'radec_err'; format = 'E'
#     name = 'claimedtype'; format = '34A'
#     name = 'redshift'; format = 'D'
#     name = 'host'; format = '43A'
#     name = 'host_ra'; format = '14A'
#     name = 'host_dec'; format = '14A'
#     name = 'ebv'; format = 'E'
#     name = 'host_ra_deg'; format = 'D'
#     name = 'host_dec_deg'; format = 'D'
#     name = 'host_dist'; format = 'E'
#     name = 'host_search_radius'; format = 'E'
#     name = 'is_confirmed_host'; format = 'J'
#     name = 'by_primary_cand'; format = 'J'
#     name = 'by_transient'; format = 'J'
#     name = 'NED_GALEX_FUV'; format = 'E'
#     name = 'NED_GALEX_FUV_Err'; format = 'E'
#     name = 'NED_GALEX_NUV'; format = 'E'
#     name = 'NED_GALEX_NUV_Err'; format = 'E'
#     name = 'NED_2MASS_J'; format = 'E'
# ...

# %%
THEx_data = hdulist[1].data
sdss_u = hdulist[1].data['NED_SDSS_u']
sdss_u_err = hdulist[1].data['NED_SDSS_u_Err']
sdss_g = hdulist[1].data['NED_SDSS_g']
sdss_g_err = hdulist[1].data['NED_SDSS_g_Err']
sdss_r = hdulist[1].data['NED_SDSS_r']
sdss_r_err = hdulist[1].data['NED_SDSS_r_Err']
sdss_i = hdulist[1].data['NED_SDSS_i']
sdss_i_err = hdulist[1].data['NED_SDSS_i_Err']
sdss_z = hdulist[1].data['NED_SDSS_z']
sdss_z_err = hdulist[1].data['NED_SDSS_z_Err']
galex_nuv = hdulist[1].data['NED_GALEX_NUV']
galex_nuv_err = hdulist[1].data['NED_GALEX_NUV_Err']
galex_fuv = hdulist[1].data['NED_GALEX_FUV']
galex_fuv_err = hdulist[1].data['NED_GALEX_FUV_Err']
# Out:
# CC, II
# CC, II
# CC, I, Ib
# CC, I, Ic
# I, Ia
# I, I Pec, Ia, Ia Pec, Ia-91T
# CC, I, II, Ia
# I, Ia
# CC, I, Ib
# I, I Pec, Ia, Ia Pec, Ia-HV
# I, Ia
# I, Ia
# CC, II, II P
# I, Ia
# CC, II
# I, Ia
# I, Ia
# CC, II
# CC, II
# I, Ia
# I, Ia
# I, Ia
# CC, I, II, Ia
# CC, II
# I, Ia
# I, Ia
# I, Ia
# CC, II, IIb
# I, Ia
# CC, II
# CC, II
# I, Ia
# I, Ia, nIa
# CC, I, Ib/c, Ic
# I, Ia
# CC, II
# I, Ia
# I, Ia
# CC, II
# I, Ia
# I, Ia
# I, Ia
# I, Ia
# I, Ia
# CC, II
# I, Ia
# CC, II
# CC, I, Ib/c, Ic
# CC, II, II P, II P Pec, II Pec
# I, Ia
# CC, II, II L
# CC, I, II, Ic
# I, Ia
# CC, I, II, IIb, Ia, Ib/c
# I, Ia
# I, Ia
# I, Ia
# I, Ia
# CC, II
# I, Ia
# I, Ia
# I, Ia
# I, Ia
# I, Ia
# I, Ia
# CC, II
# CC, II
# I, Ia
# I, Ia
# I, Ia
# I, Ia
# I, Ia
# I, Ia
# I, Ia
# I, Ia
# I, Ia
# I, Ia
# CC, II
# I, Ia
# CC, II
# CC, I, Ib, Ic
# I, Ia
# CC, II
# I, I Pec, Ia, Ia Pec
# I, I Pec, Ia, Ia Pec, Ia-HV
# I, I Pec, Ia, Ia Pec, Ia-HV
# I, I Pec, Ia, Ia Pec, Ia-HV
# CC, II
# CC, II
# CC, II
# ...

# %%
features = [280,281,282,283,284,61,63,65,67]

corr = np.zeros([len(features), len(features)])


for j in range(len(features)):
    for k in range(len(features)):
        X=[]
        Y=[]
        for i in range(len(THEx_data)):
            if str(THEx_data[i][features[j]])!='nan' and str(THEx_data[i][features[k]])!='nan':
                X.append(THEx_data[i][features[j]])
                Y.append(THEx_data[i][features[k]])
        corr[j][k] = list(stats.pearsonr(X, Y))[0]
print corr
# Out:
# [[ 1.          0.38434573  0.42621665 -0.37049439 -0.14814325 -0.04779678
#   -0.03595262  0.06791474  0.08187153]
#  [ 0.38434573  1.          0.44562821  0.15896243 -0.11311844 -0.15489756
#   -0.13791513  0.05849258  0.07918341]
#  [ 0.42621665  0.44562821  1.         -0.03787219 -0.22006541  0.17016289
#    0.17536113  0.31839345  0.25816492]
#  [-0.37049439  0.15896243 -0.03787219  1.          0.03755134 -0.02839168
#   -0.038609   -0.10553112 -0.13321156]
#  [-0.14814325 -0.11311844 -0.22006541  0.03755134  1.         -0.21080496
#   -0.21576352 -0.31861965 -0.26716188]
#  [-0.04779678 -0.15489756  0.17016289 -0.02839168 -0.21080496  1.
#    0.99161184  0.85521221  0.7337141 ]
#  [-0.03595262 -0.13791513  0.17536113 -0.038609   -0.21576352  0.99161184
#    1.          0.87471569  0.75940734]
#  [ 0.06791474  0.05849258  0.31839345 -0.10553112 -0.31861965  0.85521221
#    0.87471569  1.          0.93347913]
# ...

# %%
corr_ = np.absolute(corr)
print corr_
# Out:
# [[ 1.          0.38434573  0.42621665  0.37049439  0.14814325  0.04779678
#    0.03595262  0.06791474  0.08187153]
#  [ 0.38434573  1.          0.44562821  0.15896243  0.11311844  0.15489756
#    0.13791513  0.05849258  0.07918341]
#  [ 0.42621665  0.44562821  1.          0.03787219  0.22006541  0.17016289
#    0.17536113  0.31839345  0.25816492]
#  [ 0.37049439  0.15896243  0.03787219  1.          0.03755134  0.02839168
#    0.038609    0.10553112  0.13321156]
#  [ 0.14814325  0.11311844  0.22006541  0.03755134  1.          0.21080496
#    0.21576352  0.31861965  0.26716188]
#  [ 0.04779678  0.15489756  0.17016289  0.02839168  0.21080496  1.
#    0.99161184  0.85521221  0.7337141 ]
#  [ 0.03595262  0.13791513  0.17536113  0.038609    0.21576352  0.99161184
#    1.          0.87471569  0.75940734]
#  [ 0.06791474  0.05849258  0.31839345  0.10553112  0.31861965  0.85521221
#    0.87471569  1.          0.93347913]
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

alpha = ['Firefly_age_lightW', 'metallicity_lightW', 'stellar_mass', 'spm_EBV', 'nComponentsSSP','ALLWISE_w1','ALLWISE_w2', 'ALLWISE_w3','ALLWISE_w4']

fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111)
cax = ax.matshow(corr_, interpolation='nearest')
fig.colorbar(cax)

ax.set_xticklabels(['']+alpha, rotation=90)
ax.set_yticklabels(['']+alpha)

plt.show()

# %%
    name = 'event'; format = '30A'
    name = 'ra'; format = '14A'
    name = 'dec'; format = '14A'
    name = 'ra_deg'; format = 'D'
    name = 'dec_deg'; format = 'D'
    name = 'radec_err'; format = 'E'
    name = 'claimedtype'; format = '34A'
    name = 'redshift'; format = 'D'
    name = 'host'; format = '43A'
    name = 'host_ra'; format = '14A'
    name = 'host_dec'; format = '14A'
    name = 'ebv'; format = 'E'
    name = 'host_ra_deg'; format = 'D'
    name = 'host_dec_deg'; format = 'D'
    name = 'host_dist'; format = 'E'
    name = 'host_search_radius'; format = 'E'
    name = 'is_confirmed_host'; format = 'J'
    name = 'by_primary_cand'; format = 'J'
    name = 'by_transient'; format = 'J'
    name = 'NED_GALEX_FUV'; format = 'E'
    name = 'NED_GALEX_FUV_Err'; format = 'E'
    name = 'NED_GALEX_NUV'; format = 'E'
    name = 'NED_GALEX_NUV_Err'; format = 'E'
    name = 'NED_2MASS_J'; format = 'E'
    name = 'NED_2MASS_J_Err'; format = 'E'
    name = 'NED_2MASS_H'; format = 'E'
    name = 'NED_2MASS_H_Err'; format = 'E'
    name = 'NED_2MASS_Ks'; format = 'E'
    name = 'NED_2MASS_Ks_Err'; format = 'E'
    name = 'NED_SDSS_u'; format = 'E'
    name = 'NED_SDSS_u_Err'; format = 'E'
    name = 'NED_SDSS_g'; format = 'E'
    name = 'NED_SDSS_g_Err'; format = 'E'
    name = 'NED_SDSS_r'; format = 'E'
    name = 'NED_SDSS_r_Err'; format = 'E'
    name = 'NED_SDSS_i'; format = 'E'
    name = 'NED_SDSS_i_Err'; format = 'E'
    name = 'NED_SDSS_z'; format = 'E'
    name = 'NED_SDSS_z_Err'; format = 'E'
    name = 'NED_IRAC_36'; format = 'E'
    name = 'NED_IRAC_36_Err'; format = 'E'
    name = 'NED_IRAC_45'; format = 'E'
    name = 'NED_IRAC_45_Err'; format = 'E'
    name = 'NED_IRAC_58'; format = 'E'
    name = 'NED_IRAC_58_Err'; format = 'E'
    name = 'NED_IRAC_80'; format = 'E'
    name = 'NED_IRAC_80_Err'; format = 'E'
    name = 'NED_IRAS_12'; format = 'E'
    name = 'NED_IRAS_12_Err'; format = 'E'
    name = 'NED_IRAS_25'; format = 'E'
    name = 'NED_IRAS_25_Err'; format = 'E'
    name = 'NED_IRAS_60'; format = 'E'
    name = 'NED_IRAS_60_Err'; format = 'E'
    name = 'NED_IRAS_100'; format = 'E'
    name = 'NED_IRAS_100_Err'; format = 'E'
    name = 'NED_MIPS_24'; format = 'E'
    name = 'NED_MIPS_24_Err'; format = 'E'
    name = 'NED_HI'; format = 'E'
    name = 'NED_HI_Err'; format = 'E'
    name = 'NED_RC3_B'; format = 'E'
    name = 'NED_RC3_B_Err'; format = 'E'
    name = 'AllWISE_W1mag'; format = 'E'
    name = 'AllWISE_W1mag_Err'; format = 'E'
    name = 'AllWISE_W2mag'; format = 'E'
    name = 'AllWISE_W2mag_Err'; format = 'E'
    name = 'AllWISE_W3mag'; format = 'E'
    name = 'AllWISE_W3mag_Err'; format = 'E'
    name = 'AllWISE_W4mag'; format = 'E'
    name = 'AllWISE_W4mag_Err'; format = 'E'
    name = 'AllWISE_Jmag'; format = 'E'
    name = 'AllWISE_Jmag_Err'; format = 'E'
    name = 'AllWISE_Hmag'; format = 'E'
    name = 'AllWISE_Hmag_Err'; format = 'E'
    name = 'AllWISE_Kmag'; format = 'E'
    name = 'AllWISE_Kmag_Err'; format = 'E'
    name = 'AllWISE_IsExtSrc'; format = 'B'
    name = 'AllWISE_IsVar'; format = '4A'
    name = 'PS1_gmag'; format = 'D'
    name = 'PS1_e_gmag'; format = 'E'
    name = 'PS1_gKmag'; format = 'D'
    name = 'PS1_e_gKmag'; format = 'E'
    name = 'PS1_rmag'; format = 'D'
    name = 'PS1_e_rmag'; format = 'E'
    name = 'PS1_rKmag'; format = 'D'
    name = 'PS1_e_rKmag'; format = 'E'
    name = 'PS1_imag'; format = 'D'
    name = 'PS1_e_imag'; format = 'E'
    name = 'PS1_iKmag'; format = 'D'
    name = 'PS1_e_iKmag'; format = 'E'
    name = 'PS1_zmag'; format = 'D'
    name = 'PS1_e_zmag'; format = 'E'
    name = 'PS1_zKmag'; format = 'D'
    name = 'PS1_e_zKmag'; format = 'E'
    name = 'PS1_ymag'; format = 'D'
    name = 'PS1_e_ymag'; format = 'E'
    name = 'PS1_yKmag'; format = 'D'
    name = 'PS1_e_yKmag'; format = 'E'
    name = 'SCOS_Bmag'; format = 'E'
    name = 'SCOS_Bcal'; format = 'E'
    name = 'SCOS_Bcc'; format = 'E'
    name = 'SCOS_Rmag'; format = 'E'
    name = 'SCOS_Rcal'; format = 'E'
    name = 'SCOS_Rcc'; format = 'E'
    name = 'SCOS_Imag'; format = 'E'
    name = 'SCOS_Ical'; format = 'E'
    name = 'SCOS_Icc'; format = 'E'
    name = 'SCOS_Ebm'; format = 'E'
    name = 'MPAJHU_SIGMA_BALMER'; format = 'E'
    name = 'MPAJHU_SIGMA_BALMER_ERR'; format = 'E'
    name = 'MPAJHU_SIGMA_FORBIDDEN'; format = 'E'
    name = 'MPAJHU_SIGMA_FORBIDDEN_ERR'; format = 'E'
    name = 'MPAJHU_OII_3726_EQW'; format = 'E'
    name = 'MPAJHU_OII_3726_EQW_ERR'; format = 'E'
    name = 'MPAJHU_OII_3726_FLUX'; format = 'E'
    name = 'MPAJHU_OII_3726_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_OII_3729_EQW'; format = 'E'
    name = 'MPAJHU_OII_3729_EQW_ERR'; format = 'E'
    name = 'MPAJHU_OII_3729_FLUX'; format = 'E'
    name = 'MPAJHU_OII_3729_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_NEIII_3869_EQW'; format = 'E'
    name = 'MPAJHU_NEIII_3869_EQW_ERR'; format = 'E'
    name = 'MPAJHU_NEIII_3869_FLUX'; format = 'E'
    name = 'MPAJHU_NEIII_3869_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_H_DELTA_EQW'; format = 'E'
    name = 'MPAJHU_H_DELTA_EQW_ERR'; format = 'E'
    name = 'MPAJHU_H_DELTA_FLUX'; format = 'E'
    name = 'MPAJHU_H_DELTA_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_H_GAMMA_EQW'; format = 'E'
    name = 'MPAJHU_H_GAMMA_EQW_ERR'; format = 'E'
    name = 'MPAJHU_H_GAMMA_FLUX'; format = 'E'
    name = 'MPAJHU_H_GAMMA_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_OIII_4363_EQW'; format = 'E'
    name = 'MPAJHU_OIII_4363_EQW_ERR'; format = 'E'
    name = 'MPAJHU_OIII_4363_FLUX'; format = 'E'
    name = 'MPAJHU_OIII_4363_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_H_BETA_EQW'; format = 'E'
    name = 'MPAJHU_H_BETA_EQW_ERR'; format = 'E'
    name = 'MPAJHU_H_BETA_FLUX'; format = 'E'
    name = 'MPAJHU_H_BETA_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_OIII_4959_EQW'; format = 'E'
    name = 'MPAJHU_OIII_4959_EQW_ERR'; format = 'E'
    name = 'MPAJHU_OIII_4959_FLUX'; format = 'E'
    name = 'MPAJHU_OIII_4959_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_OIII_5007_EQW'; format = 'E'
    name = 'MPAJHU_OIII_5007_EQW_ERR'; format = 'E'
    name = 'MPAJHU_OIII_5007_FLUX'; format = 'E'
    name = 'MPAJHU_OIII_5007_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_HEI_5876_EQW'; format = 'E'
    name = 'MPAJHU_HEI_5876_EQW_ERR'; format = 'E'
    name = 'MPAJHU_HEI_5876_FLUX'; format = 'E'
    name = 'MPAJHU_HEI_5876_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_OI_6300_EQW'; format = 'E'
    name = 'MPAJHU_OI_6300_EQW_ERR'; format = 'E'
    name = 'MPAJHU_OI_6300_FLUX'; format = 'E'
    name = 'MPAJHU_OI_6300_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_NII_6548_EQW'; format = 'E'
    name = 'MPAJHU_NII_6548_EQW_ERR'; format = 'E'
    name = 'MPAJHU_NII_6548_FLUX'; format = 'E'
    name = 'MPAJHU_NII_6548_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_H_ALPHA_EQW'; format = 'E'
    name = 'MPAJHU_H_ALPHA_EQW_ERR'; format = 'E'
    name = 'MPAJHU_H_ALPHA_FLUX'; format = 'E'
    name = 'MPAJHU_H_ALPHA_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_NII_6584_EQW'; format = 'E'
    name = 'MPAJHU_NII_6584_EQW_ERR'; format = 'E'
    name = 'MPAJHU_NII_6584_FLUX'; format = 'E'
    name = 'MPAJHU_NII_6584_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_SII_6717_EQW'; format = 'E'
    name = 'MPAJHU_SII_6717_EQW_ERR'; format = 'E'
    name = 'MPAJHU_SII_6717_FLUX'; format = 'E'
    name = 'MPAJHU_SII_6717_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_SII_6731_EQW'; format = 'E'
    name = 'MPAJHU_SII_6731_EQW_ERR'; format = 'E'
    name = 'MPAJHU_SII_6731_FLUX'; format = 'E'
    name = 'MPAJHU_SII_6731_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_ARIII7135_EQW'; format = 'E'
    name = 'MPAJHU_ARIII7135_EQW_ERR'; format = 'E'
    name = 'MPAJHU_ARIII7135_FLUX'; format = 'E'
    name = 'MPAJHU_ARIII7135_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_H_DELTA_ABS'; format = 'E'
    name = 'MPAJHU_H_GAMMA_ABS'; format = 'E'
    name = 'MPAJHU_H_BETA_ABS'; format = 'E'
    name = 'MPAJHU_H_ALPHA_ABS'; format = 'E'
    name = 'MPAJHU_CA_K_ABS'; format = 'E'
    name = 'MPAJHU_CA_H_ABS'; format = 'E'
    name = 'MPAJHU_NA_D_ABS'; format = 'E'
    name = 'MPAJHU_OII_SIGMA'; format = 'E'
    name = 'MPAJHU_OII_FLUX'; format = 'E'
    name = 'MPAJHU_OII_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_OIII_SIGMA'; format = 'E'
    name = 'MPAJHU_OIII_FLUX'; format = 'E'
    name = 'MPAJHU_OIII_FLUX_ERR'; format = 'E'
    name = 'MPAJHU_LICK_CN1'; format = 'E'
    name = 'MPAJHU_LICK_CN1_ERR'; format = 'E'
    name = 'MPAJHU_LICK_CN2'; format = 'E'
    name = 'MPAJHU_LICK_CN2_ERR'; format = 'E'
    name = 'MPAJHU_LICK_CA4227'; format = 'E'
    name = 'MPAJHU_LICK_CA4227_ERR'; format = 'E'
    name = 'MPAJHU_LICK_G4300'; format = 'E'
    name = 'MPAJHU_LICK_G4300_ERR'; format = 'E'
    name = 'MPAJHU_LICK_FE4383'; format = 'E'
    name = 'MPAJHU_LICK_FE4383_ERR'; format = 'E'
    name = 'MPAJHU_LICK_CA4455'; format = 'E'
    name = 'MPAJHU_LICK_CA4455_ERR'; format = 'E'
    name = 'MPAJHU_LICK_FE4531'; format = 'E'
    name = 'MPAJHU_LICK_FE4531_ERR'; format = 'E'
    name = 'MPAJHU_LICK_C4668'; format = 'E'
    name = 'MPAJHU_LICK_C4668_ERR'; format = 'E'
    name = 'MPAJHU_LICK_HB'; format = 'E'
    name = 'MPAJHU_LICK_HB_ERR'; format = 'E'
    name = 'MPAJHU_LICK_FE5015'; format = 'E'
    name = 'MPAJHU_LICK_FE5015_ERR'; format = 'E'
    name = 'MPAJHU_LICK_MG1'; format = 'E'
    name = 'MPAJHU_LICK_MG1_ERR'; format = 'E'
    name = 'MPAJHU_LICK_MG2'; format = 'E'
    name = 'MPAJHU_LICK_MG2_ERR'; format = 'E'
    name = 'MPAJHU_LICK_MGB'; format = 'E'
    name = 'MPAJHU_LICK_MGB_ERR'; format = 'E'
    name = 'MPAJHU_LICK_FE5270'; format = 'E'
    name = 'MPAJHU_LICK_FE5270_ERR'; format = 'E'
    name = 'MPAJHU_LICK_FE5335'; format = 'E'
    name = 'MPAJHU_LICK_FE5335_ERR'; format = 'E'
    name = 'MPAJHU_LICK_FE5406'; format = 'E'
    name = 'MPAJHU_LICK_FE5406_ERR'; format = 'E'
    name = 'MPAJHU_LICK_FE5709'; format = 'E'
    name = 'MPAJHU_LICK_FE5709_ERR'; format = 'E'
    name = 'MPAJHU_LICK_FE5782'; format = 'E'
    name = 'MPAJHU_LICK_FE5782_ERR'; format = 'E'
    name = 'MPAJHU_LICK_NAD'; format = 'E'
    name = 'MPAJHU_LICK_NAD_ERR'; format = 'E'
    name = 'MPAJHU_LICK_TIO1'; format = 'E'
    name = 'MPAJHU_LICK_TIO1_ERR'; format = 'E'
    name = 'MPAJHU_LICK_TIO2'; format = 'E'
    name = 'MPAJHU_LICK_TIO2_ERR'; format = 'E'
    name = 'MPAJHU_LICK_HD_A'; format = 'E'
    name = 'MPAJHU_LICK_HD_A_ERR'; format = 'E'
    name = 'MPAJHU_LICK_HG_A'; format = 'E'
    name = 'MPAJHU_LICK_HG_A_ERR'; format = 'E'
    name = 'MPAJHU_LICK_HD_F'; format = 'E'
    name = 'MPAJHU_LICK_HD_F_ERR'; format = 'E'
    name = 'MPAJHU_LICK_HG_F'; format = 'E'
    name = 'MPAJHU_LICK_HG_F_ERR'; format = 'E'
    name = 'MPAJHU_DTT_CAII8498'; format = 'E'
    name = 'MPAJHU_DTT_CAII8498_ERR'; format = 'E'
    name = 'MPAJHU_DTT_CAII8542'; format = 'E'
    name = 'MPAJHU_DTT_CAII8542_ERR'; format = 'E'
    name = 'MPAJHU_DTT_CAII8662'; format = 'E'
    name = 'MPAJHU_DTT_CAII8662_ERR'; format = 'E'
    name = 'MPAJHU_DTT_MGI8807'; format = 'E'
    name = 'MPAJHU_DTT_MGI8807_ERR'; format = 'E'
    name = 'MPAJHU_BH_CNB'; format = 'E'
    name = 'MPAJHU_BH_CNB_ERR'; format = 'E'
    name = 'MPAJHU_BH_HK'; format = 'E'
    name = 'MPAJHU_BH_HK_ERR'; format = 'E'
    name = 'MPAJHU_BH_CAI'; format = 'E'
    name = 'MPAJHU_BH_CAI_ERR'; format = 'E'
    name = 'MPAJHU_BH_G'; format = 'E'
    name = 'MPAJHU_BH_G_ERR'; format = 'E'
    name = 'MPAJHU_BH_HB'; format = 'E'
    name = 'MPAJHU_BH_HB_ERR'; format = 'E'
    name = 'MPAJHU_BH_MGG'; format = 'E'
    name = 'MPAJHU_BH_MGG_ERR'; format = 'E'
    name = 'MPAJHU_BH_MH'; format = 'E'
    name = 'MPAJHU_BH_MH_ERR'; format = 'E'
    name = 'MPAJHU_BH_FC'; format = 'E'
    name = 'MPAJHU_BH_FC_ERR'; format = 'E'
    name = 'MPAJHU_BH_NAD'; format = 'E'
    name = 'MPAJHU_BH_NAD_ERR'; format = 'E'
    name = 'MPAJHU_D4000'; format = 'E'
    name = 'MPAJHU_D4000_ERR'; format = 'E'
    name = 'MPAJHU_D4000_RED'; format = 'E'
    name = 'MPAJHU_D4000_BLUE'; format = 'E'
    name = 'MPAJHU_BPTCLASS'; format = 'I'
    name = 'MPAJHU_LGM_TOT_P50'; format = 'E'
    name = 'MPAJHU_LGM_FIB_P50'; format = 'E'
    name = 'MPAJHU_OH_P50'; format = 'E'
    name = 'MPAJHU_SFR_TOT_P50'; format = 'E'
    name = 'MPAJHU_SFR_FIB_P50'; format = 'E'
    name = 'MPAJHU_SPECSFR_TOT_P50'; format = 'E'
    name = 'MPAJHU_SPECSFR_FIB_P50'; format = 'E'
    name = 'Firefly_Chabrier_MILES_age_lightW'; format = 'D'
    name = 'Firefly_Chabrier_MILES_metallicity_lightW'; format = 'D'
    name = 'Firefly_Chabrier_MILES_stellar_mass'; format = 'D'
    name = 'Firefly_Chabrier_MILES_spm_EBV'; format = 'D'
    name = 'Firefly_Chabrier_MILES_nComponentsSSP'; format = 'D'
    name = 'Firefly_Salpeter_MILES_age_lightW'; format = 'D'
    name = 'Firefly_Salpeter_MILES_metallicity_lightW'; format = 'D'
    name = 'Firefly_Salpeter_MILES_stellar_mass'; format = 'D'
    name = 'Firefly_Salpeter_MILES_spm_EBV'; format = 'D'
    name = 'Firefly_Salpeter_MILES_nComponentsSSP'; format = 'D'
    name = 'Firefly_Kroupa_MILES_age_lightW'; format = 'D'
    name = 'Firefly_Kroupa_MILES_metallicity_lightW'; format = 'D'
    name = 'Firefly_Kroupa_MILES_stellar_mass'; format = 'D'
    name = 'Firefly_Kroupa_MILES_spm_EBV'; format = 'D'
    name = 'Firefly_Kroupa_MILES_nSSP'; format = 'D'
    name = 'WiscPCA_MSTELLAR_MEDIAN'; format = 'D'
    name = 'WiscPCA_MSTELLAR_ERR'; format = 'D'
    name = 'WiscPCA_VDISP_MEDIAN'; format = 'D'
    name = 'WiscPCA_VDISP_ERR'; format = 'D'
    name = 'WiscPCA_CALPHA_NORM'; format = 'D'
    name = 'GSWLC_logMstar'; format = 'E'
    name = 'GSWLC_logMstar_Err'; format = 'E'
    name = 'GSWLC_logSFR'; format = 'E'
    name = 'GSWLC_logSFR_Err'; format = 'E'
    name = 'GSWLC_A_FUV'; format = 'E'
    name = 'GSWLC_A_FUV_Err'; format = 'E'
    name = 'GSWLC_A_B'; format = 'E'
    name = 'GSWLC_A_B_Err'; format = 'E'
    name = 'GSWLC_A_V'; format = 'E'
    name = 'GSWLC_A_V_Err'; format = 'E'
    name = 'HyperLEDA_objtype'; format = '4A'
    name = 'HyperLEDA_type'; format = '6A'
    name = 'HyperLEDA_bar'; format = '3A'
    name = 'HyperLEDA_ring'; format = '3A'
    name = 'HyperLEDA_multiple'; format = '3A'
    name = 'HyperLEDA_compactness'; format = '3A'
    name = 'HyperLEDA_t'; format = 'D'
    name = 'HyperLEDA_e_t'; format = 'D'
    name = 'HyperLEDA_agnclass'; format = '6A'
    name = 'HyperLEDA_logd25'; format = 'D'
    name = 'HyperLEDA_e_logd25'; format = 'D'
    name = 'HyperLEDA_logr25'; format = 'D'
    name = 'HyperLEDA_e_logr25'; format = 'D'
    name = 'HyperLEDA_pa'; format = 'D'
    name = 'HyperLEDA_brief'; format = 'D'
    name = 'HyperLEDA_e_brief'; format = 'D'
    name = 'HyperLEDA_ut'; format = 'D'
    name = 'HyperLEDA_e_ut'; format = 'D'
    name = 'HyperLEDA_bt'; format = 'D'
    name = 'HyperLEDA_e_bt'; format = 'D'
    name = 'HyperLEDA_vt'; format = 'D'
    name = 'HyperLEDA_e_vt'; format = 'D'
    name = 'HyperLEDA_it'; format = 'D'
    name = 'HyperLEDA_e_it'; format = 'D'
    name = 'HyperLEDA_kt'; format = 'D'
    name = 'HyperLEDA_e_kt'; format = 'D'
    name = 'HyperLEDA_m21'; format = 'D'
    name = 'HyperLEDA_e_m21'; format = 'D'
    name = 'HyperLEDA_mfir'; format = 'D'
    name = 'HyperLEDA_ube'; format = 'D'
    name = 'HyperLEDA_bve'; format = 'D'
    name = 'HyperLEDA_vmaxg'; format = 'D'
    name = 'HyperLEDA_e_vmaxg'; format = 'D'
    name = 'HyperLEDA_vmaxs'; format = 'D'
    name = 'HyperLEDA_e_vmaxs'; format = 'D'
    name = 'HyperLEDA_vdis'; format = 'D'
    name = 'HyperLEDA_e_vdis'; format = 'D'
    name = 'HyperLEDA_vrad'; format = 'D'
    name = 'HyperLEDA_e_vrad'; format = 'D'
    name = 'HyperLEDA_vopt'; format = 'D'
    name = 'HyperLEDA_e_vopt'; format = 'D'
    name = 'HyperLEDA_v'; format = 'D'
    name = 'HyperLEDA_e_v'; format = 'D'
    name = 'HyperLEDA_ag'; format = 'D'
    name = 'HyperLEDA_ai'; format = 'D'
    name = 'HyperLEDA_incl'; format = 'D'
    name = 'HyperLEDA_a21'; format = 'D'
    name = 'HyperLEDA_logdc'; format = 'D'
    name = 'HyperLEDA_btc'; format = 'D'
    name = 'HyperLEDA_itc'; format = 'D'
    name = 'HyperLEDA_ubtc'; format = 'D'
    name = 'HyperLEDA_bvtc'; format = 'D'
    name = 'HyperLEDA_bri25'; format = 'D'
    name = 'HyperLEDA_vrot'; format = 'D'
    name = 'HyperLEDA_e_vrot'; format = 'D'
    name = 'HyperLEDA_mg2'; format = 'D'
    name = 'HyperLEDA_e_mg2'; format = 'D'
    name = 'HyperLEDA_m21c'; format = 'D'
    name = 'HyperLEDA_hic'; format = 'D'
    name = 'HyperLEDA_vlg'; format = 'D'
    name = 'HyperLEDA_vgsr'; format = 'D'
    name = 'HyperLEDA_vvir'; format = 'D'
    name = 'HyperLEDA_v3k'; format = 'D'
    name = 'HyperLEDA_modz'; format = 'D'
    name = 'HyperLEDA_e_modz'; format = 'D'
    name = 'HyperLEDA_mod0'; format = 'D'
    name = 'HyperLEDA_e_mod0'; format = 'D'
    name = 'HyperLEDA_modbest'; format = 'D'
    name = 'HyperLEDA_e_modbest'; format = 'D'
    name = 'HyperLEDA_mabs'; format = 'D'
    name = 'HyperLEDA_e_mabs'; format = 'D'
    name = 'NSA_SERSIC_NMGY_FUV'; format = 'E'
    name = 'NSA_SERSIC_NMGY_NUV'; format = 'E'
    name = 'NSA_SERSIC_NMGY_u'; format = 'E'
    name = 'NSA_SERSIC_NMGY_g'; format = 'E'
    name = 'NSA_SERSIC_NMGY_r'; format = 'E'
    name = 'NSA_SERSIC_NMGY_i'; format = 'E'
    name = 'NSA_SERSIC_NMGY_z'; format = 'E'
    name = 'NSA_SERSIC_NMGY_IVAR_FUV'; format = 'E'
    name = 'NSA_SERSIC_NMGY_IVAR_NUV'; format = 'E'
    name = 'NSA_SERSIC_NMGY_IVAR_u'; format = 'E'
    name = 'NSA_SERSIC_NMGY_IVAR_g'; format = 'E'
    name = 'NSA_SERSIC_NMGY_IVAR_r'; format = 'E'
    name = 'NSA_SERSIC_NMGY_IVAR_i'; format = 'E'
    name = 'NSA_SERSIC_NMGY_IVAR_z'; format = 'E'
    name = 'NSA_SERSIC_OK'; format = 'I'
    name = 'NSA_SERSIC_RNMGY_FUV'; format = 'E'
    name = 'NSA_SERSIC_RNMGY_NUV'; format = 'E'
    name = 'NSA_SERSIC_RNMGY_u'; format = 'E'
    name = 'NSA_SERSIC_RNMGY_g'; format = 'E'
    name = 'NSA_SERSIC_RNMGY_r'; format = 'E'
    name = 'NSA_SERSIC_RNMGY_i'; format = 'E'
    name = 'NSA_SERSIC_RNMGY_z'; format = 'E'
    name = 'NSA_SERSIC_ABSMAG_FUV'; format = 'E'
    name = 'NSA_SERSIC_ABSMAG_NUV'; format = 'E'
    name = 'NSA_SERSIC_ABSMAG_u'; format = 'E'
    name = 'NSA_SERSIC_ABSMAG_g'; format = 'E'
    name = 'NSA_SERSIC_ABSMAG_r'; format = 'E'
    name = 'NSA_SERSIC_ABSMAG_i'; format = 'E'
    name = 'NSA_SERSIC_ABSMAG_z'; format = 'E'
    name = 'NSA_SERSIC_AMIVAR_FUV'; format = 'E'
    name = 'NSA_SERSIC_AMIVAR_NUV'; format = 'E'
    name = 'NSA_SERSIC_AMIVAR_u'; format = 'E'
    name = 'NSA_SERSIC_AMIVAR_g'; format = 'E'
    name = 'NSA_SERSIC_AMIVAR_r'; format = 'E'
    name = 'NSA_SERSIC_AMIVAR_i'; format = 'E'
    name = 'NSA_SERSIC_AMIVAR_z'; format = 'E'
    name = 'NSA_EXTINCTION_FUV'; format = 'E'
    name = 'NSA_EXTINCTION_NUV'; format = 'E'
    name = 'NSA_EXTINCTION_u'; format = 'E'
    name = 'NSA_EXTINCTION_g'; format = 'E'
    name = 'NSA_EXTINCTION_r'; format = 'E'
    name = 'NSA_EXTINCTION_i'; format = 'E'
    name = 'NSA_EXTINCTION_z'; format = 'E'
    name = 'NSA_SERSIC_KCORRECT_FUV'; format = 'E'
    name = 'NSA_SERSIC_KCORRECT_NUV'; format = 'E'
    name = 'NSA_SERSIC_KCORRECT_u'; format = 'E'
    name = 'NSA_SERSIC_KCORRECT_g'; format = 'E'
    name = 'NSA_SERSIC_KCORRECT_r'; format = 'E'
    name = 'NSA_SERSIC_KCORRECT_i'; format = 'E'
    name = 'NSA_SERSIC_KCORRECT_z'; format = 'E'
    name = 'NSA_SERSIC_MTOL_FUV'; format = 'E'
    name = 'NSA_SERSIC_MTOL_NUV'; format = 'E'
    name = 'NSA_SERSIC_MTOL_u'; format = 'E'
    name = 'NSA_SERSIC_MTOL_g'; format = 'E'
    name = 'NSA_SERSIC_MTOL_r'; format = 'E'
    name = 'NSA_SERSIC_MTOL_i'; format = 'E'
    name = 'NSA_SERSIC_MTOL_z'; format = 'E'
    name = 'NSA_SERSIC_B300'; format = 'E'
    name = 'NSA_SERSIC_B1000'; format = 'E'
    name = 'NSA_SERSIC_METS'; format = 'E'
    name = 'NSA_SERSIC_MASS'; format = 'E'
    name = 'NSA_PETRO_FLUX_FUV'; format = 'E'
    name = 'NSA_PETRO_FLUX_NUV'; format = 'E'
    name = 'NSA_PETRO_FLUX_u'; format = 'E'
    name = 'NSA_PETRO_FLUX_g'; format = 'E'
    name = 'NSA_PETRO_FLUX_r'; format = 'E'
    name = 'NSA_PETRO_FLUX_i'; format = 'E'
    name = 'NSA_PETRO_FLUX_z'; format = 'E'
    name = 'NSA_PETRO_FLUX_IVAR_FUV'; format = 'E'
    name = 'NSA_PETRO_FLUX_IVAR_NUV'; format = 'E'
    name = 'NSA_PETRO_FLUX_IVAR_u'; format = 'E'
    name = 'NSA_PETRO_FLUX_IVAR_g'; format = 'E'
    name = 'NSA_PETRO_FLUX_IVAR_r'; format = 'E'
    name = 'NSA_PETRO_FLUX_IVAR_i'; format = 'E'
    name = 'NSA_PETRO_FLUX_IVAR_z'; format = 'E'
    name = 'NSA_PETRO_BA50'; format = 'E'
    name = 'NSA_PETRO_PHI50'; format = 'E'
    name = 'NSA_PETRO_BA90'; format = 'E'
    name = 'NSA_PETRO_PHI90'; format = 'E'
    name = 'NSA_SERSIC_FLUX_FUV'; format = 'E'
    name = 'NSA_SERSIC_FLUX_NUV'; format = 'E'
    name = 'NSA_SERSIC_FLUX_u'; format = 'E'
    name = 'NSA_SERSIC_FLUX_g'; format = 'E'
    name = 'NSA_SERSIC_FLUX_r'; format = 'E'
    name = 'NSA_SERSIC_FLUX_i'; format = 'E'
    name = 'NSA_SERSIC_FLUX_z'; format = 'E'
    name = 'NSA_SERSIC_FLUX_IVAR_FUV'; format = 'E'
    name = 'NSA_SERSIC_FLUX_IVAR_NUV'; format = 'E'
    name = 'NSA_SERSIC_FLUX_IVAR_u'; format = 'E'
    name = 'NSA_SERSIC_FLUX_IVAR_g'; format = 'E'
    name = 'NSA_SERSIC_FLUX_IVAR_r'; format = 'E'
    name = 'NSA_SERSIC_FLUX_IVAR_i'; format = 'E'
    name = 'NSA_SERSIC_FLUX_IVAR_z'; format = 'E'
    name = 'NSA_SERSIC_N'; format = 'E'
    name = 'NSA_SERSIC_BA'; format = 'E'
    name = 'NSA_SERSIC_PHI'; format = 'E'
    name = 'NSA_ASYMMETRY_FUV'; format = 'E'
    name = 'NSA_ASYMMETRY_NUV'; format = 'E'
    name = 'NSA_ASYMMETRY_u'; format = 'E'
    name = 'NSA_ASYMMETRY_g'; format = 'E'
    name = 'NSA_ASYMMETRY_r'; format = 'E'
    name = 'NSA_ASYMMETRY_i'; format = 'E'
    name = 'NSA_ASYMMETRY_z'; format = 'E'
    name = 'NSA_CLUMPY_FUV'; format = 'E'
    name = 'NSA_CLUMPY_NUV'; format = 'E'
    name = 'NSA_CLUMPY_u'; format = 'E'
    name = 'NSA_CLUMPY_g'; format = 'E'
    name = 'NSA_CLUMPY_r'; format = 'E'
    name = 'NSA_CLUMPY_i'; format = 'E'
    name = 'NSA_CLUMPY_z'; format = 'E'
    name = 'NSA_PETRO_THETA'; format = 'E'
    name = 'NSA_PETRO_TH50'; format = 'E'
    name = 'NSA_PETRO_TH90'; format = 'E'
    name = 'NSA_SERSIC_TH50'; format = 'E'
    name = 'NSA_ELPETRO_BA'; format = 'E'
    name = 'NSA_ELPETRO_PHI'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_R'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_IVAR_R'; format = 'E'
    name = 'NSA_ELPETRO_THETA_R'; format = 'E'
    name = 'NSA_ELPETRO_TH50_R'; format = 'E'
    name = 'NSA_ELPETRO_TH90_R'; format = 'E'
    name = 'NSA_ELPETRO_THETA'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_FUV'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_NUV'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_u'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_g'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_r'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_i'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_z'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_IVAR_FUV'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_IVAR_NUV'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_IVAR_u'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_IVAR_g'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_IVAR_r'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_IVAR_i'; format = 'E'
    name = 'NSA_ELPETRO_FLUX_IVAR_z'; format = 'E'
    name = 'NSA_ELPETRO_TH50_FUV'; format = 'E'
    name = 'NSA_ELPETRO_TH50_NUV'; format = 'E'
    name = 'NSA_ELPETRO_TH50_u'; format = 'E'
    name = 'NSA_ELPETRO_TH50_g'; format = 'E'
    name = 'NSA_ELPETRO_TH50_r'; format = 'E'
    name = 'NSA_ELPETRO_TH50_i'; format = 'E'
    name = 'NSA_ELPETRO_TH50_z'; format = 'E'
    name = 'NSA_ELPETRO_TH90_FUV'; format = 'E'
    name = 'NSA_ELPETRO_TH90_NUV'; format = 'E'
    name = 'NSA_ELPETRO_TH90_u'; format = 'E'
    name = 'NSA_ELPETRO_TH90_g'; format = 'E'
    name = 'NSA_ELPETRO_TH90_r'; format = 'E'
    name = 'NSA_ELPETRO_TH90_i'; format = 'E'
    name = 'NSA_ELPETRO_TH90_z'; format = 'E'
    name = 'NSA_ELPETRO_APCORR_R'; format = 'E'
    name = 'NSA_ELPETRO_APCORR_FUV'; format = 'E'
    name = 'NSA_ELPETRO_APCORR_NUV'; format = 'E'
    name = 'NSA_ELPETRO_APCORR_u'; format = 'E'
    name = 'NSA_ELPETRO_APCORR_g'; format = 'E'
    name = 'NSA_ELPETRO_APCORR_r'; format = 'E'
    name = 'NSA_ELPETRO_APCORR_i'; format = 'E'
    name = 'NSA_ELPETRO_APCORR_z'; format = 'E'
    name = 'NSA_ELPETRO_APCORR_SELF_FUV'; format = 'E'
    name = 'NSA_ELPETRO_APCORR_SELF_NUV'; format = 'E'
    name = 'NSA_ELPETRO_APCORR_SELF_u'; format = 'E'
    name = 'NSA_ELPETRO_APCORR_SELF_g'; format = 'E'
    name = 'NSA_ELPETRO_APCORR_SELF_r'; format = 'E'
    name = 'NSA_ELPETRO_APCORR_SELF_i'; format = 'E'
    name = 'NSA_ELPETRO_APCORR_SELF_z'; format = 'E'
    name = 'NSA_ELPETRO_NMGY_FUV'; format = 'E'
    name = 'NSA_ELPETRO_NMGY_NUV'; format = 'E'
    name = 'NSA_ELPETRO_NMGY_u'; format = 'E'
    name = 'NSA_ELPETRO_NMGY_g'; format = 'E'
    name = 'NSA_ELPETRO_NMGY_r'; format = 'E'
    name = 'NSA_ELPETRO_NMGY_i'; format = 'E'
    name = 'NSA_ELPETRO_NMGY_z'; format = 'E'
    name = 'NSA_ELPETRO_NMGY_IVAR_FUV'; format = 'E'
    name = 'NSA_ELPETRO_NMGY_IVAR_NUV'; format = 'E'
    name = 'NSA_ELPETRO_NMGY_IVAR_u'; format = 'E'
    name = 'NSA_ELPETRO_NMGY_IVAR_g'; format = 'E'
    name = 'NSA_ELPETRO_NMGY_IVAR_r'; format = 'E'
    name = 'NSA_ELPETRO_NMGY_IVAR_i'; format = 'E'
    name = 'NSA_ELPETRO_NMGY_IVAR_z'; format = 'E'
    name = 'NSA_ELPETRO_OK'; format = 'I'
    name = 'NSA_ELPETRO_RNMGY_FUV'; format = 'E'
    name = 'NSA_ELPETRO_RNMGY_NUV'; format = 'E'
    name = 'NSA_ELPETRO_RNMGY_u'; format = 'E'
    name = 'NSA_ELPETRO_RNMGY_g'; format = 'E'
    name = 'NSA_ELPETRO_RNMGY_r'; format = 'E'
    name = 'NSA_ELPETRO_RNMGY_i'; format = 'E'
    name = 'NSA_ELPETRO_RNMGY_z'; format = 'E'
    name = 'NSA_ELPETRO_ABSMAG_FUV'; format = 'E'
    name = 'NSA_ELPETRO_ABSMAG_NUV'; format = 'E'
    name = 'NSA_ELPETRO_ABSMAG_u'; format = 'E'
    name = 'NSA_ELPETRO_ABSMAG_g'; format = 'E'
    name = 'NSA_ELPETRO_ABSMAG_r'; format = 'E'
    name = 'NSA_ELPETRO_ABSMAG_i'; format = 'E'
    name = 'NSA_ELPETRO_ABSMAG_z'; format = 'E'
    name = 'NSA_ELPETRO_AMIVAR_FUV'; format = 'E'
    name = 'NSA_ELPETRO_AMIVAR_NUV'; format = 'E'
    name = 'NSA_ELPETRO_AMIVAR_u'; format = 'E'
    name = 'NSA_ELPETRO_AMIVAR_g'; format = 'E'
    name = 'NSA_ELPETRO_AMIVAR_r'; format = 'E'
    name = 'NSA_ELPETRO_AMIVAR_i'; format = 'E'
    name = 'NSA_ELPETRO_AMIVAR_z'; format = 'E'
    name = 'NSA_ELPETRO_KCORRECT_FUV'; format = 'E'
    name = 'NSA_ELPETRO_KCORRECT_NUV'; format = 'E'
    name = 'NSA_ELPETRO_KCORRECT_u'; format = 'E'
    name = 'NSA_ELPETRO_KCORRECT_g'; format = 'E'
    name = 'NSA_ELPETRO_KCORRECT_r'; format = 'E'
    name = 'NSA_ELPETRO_KCORRECT_i'; format = 'E'
    name = 'NSA_ELPETRO_KCORRECT_z'; format = 'E'
    name = 'NSA_ELPETRO_MASS'; format = 'E'
    name = 'NSA_ELPETRO_MTOL_FUV'; format = 'E'
    name = 'NSA_ELPETRO_MTOL_NUV'; format = 'E'
    name = 'NSA_ELPETRO_MTOL_u'; format = 'E'
    name = 'NSA_ELPETRO_MTOL_g'; format = 'E'
    name = 'NSA_ELPETRO_MTOL_r'; format = 'E'
    name = 'NSA_ELPETRO_MTOL_i'; format = 'E'
    name = 'NSA_ELPETRO_MTOL_z'; format = 'E'
    name = 'NSA_ELPETRO_B300'; format = 'E'
    name = 'NSA_ELPETRO_B1000'; format = 'E'
    name = 'NSA_ELPETRO_METS'; format = 'E'
    name = 'GalaxyZoo2_Ncl'; format = 'I'
    name = 'GalaxyZoo2_Nvot'; format = 'I'
    name = 'GalaxyZoo2_Smooth'; format = 'E'
    name = 'GalaxyZoo2_FeatureOrDisk'; format = 'E'
    name = 'GalaxyZoo2_StarOrArtifact'; format = 'E'
    name = 'GalaxyZoo2_EdgeOn'; format = 'E'
    name = 'GalaxyZoo2_NotEdgeOn'; format = 'E'
    name = 'GalaxyZoo2_Bar'; format = 'E'
    name = 'GalaxyZoo2_NoBar'; format = 'E'
    name = 'GalaxyZoo2_Spiral'; format = 'E'
    name = 'GalaxyZoo2_NoSpiral'; format = 'E'
    name = 'GalaxyZoo2_NoBulge'; format = 'E'
    name = 'GalaxyZoo2_JustNoticableBulge'; format = 'E'
    name = 'GalaxyZoo2_ObviousBulge'; format = 'E'
    name = 'GalaxyZoo2_DominantBulge'; format = 'E'
    name = 'GalaxyZoo2_SomethingOdd'; format = 'E'
    name = 'GalaxyZoo2_NothingOdd'; format = 'E'
    name = 'GalaxyZoo2_SmoothAndCompletelyRound'; format = 'E'
    name = 'GalaxyZoo2_SmoothAndInbetweenRoundness'; format = 'E'
    name = 'GalaxyZoo2_SmoothAndCigarShape'; format = 'E'
    name = 'GalaxyZoo2_Ring'; format = 'E'
    name = 'GalaxyZoo2_LensOrArc'; format = 'E'
    name = 'GalaxyZoo2_DisturbedGalaxy'; format = 'E'
    name = 'GalaxyZoo2_IrregularGalaxy'; format = 'E'
    name = 'GalaxyZoo2_SomethingElseOdd'; format = 'E'
    name = 'GalaxyZoo2_Merger'; format = 'E'
    name = 'GalaxyZoo2_DustLane'; format = 'E'
    name = 'GalaxyZoo2_EdgeOnBulgeRounded'; format = 'E'
    name = 'GalaxyZoo2_EdgeOnBulgeBoxy'; format = 'E'
    name = 'GalaxyZoo2_EdgeOnBulgeNone'; format = 'E'
    name = 'GalaxyZoo2_TightlyWoundArms'; format = 'E'
    name = 'GalaxyZoo2_MediumWoundArms'; format = 'E'
    name = 'GalaxyZoo2_LooselyWoundArms'; format = 'E'
    name = 'GalaxyZoo2_OneArm'; format = 'E'
    name = 'GalaxyZoo2_TwoArms'; format = 'E'
    name = 'GalaxyZoo2_ThreeArms'; format = 'E'
    name = 'GalaxyZoo2_FourArms'; format = 'E'
    name = 'GalaxyZoo2_MultipleArms'; format = 'E'
    name = 'GalaxyZoo2_AmbigousArms'; format = 'E'
